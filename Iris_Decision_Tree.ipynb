# %% [markdown]
# <a href="https://colab.research.google.com/github/MingxiaWu/jupyterlab/blob/main/Iris_Decision_Tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier, export_text
from sklearn import tree
import matplotlib.pyplot as plt

# Load the Iris dataset as an example
iris = load_iris()
X, y = iris.data, iris.target

# Create a decision tree classifier
clf = DecisionTreeClassifier(random_state=42)

# Fit the classifier to the data
clf = clf.fit(X, y)

# Visualize the decision tree
fig, ax = plt.subplots(figsize=(12, 12))
tree.plot_tree(clf, feature_names=iris.feature_names, class_names=iris.target_names, filled=True, rounded=True, ax=ax)

plt.show()

# %%
# Import necessary libraries
import pandas as pd

# Load the Iris dataset as a DataFrame
iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
iris_df['target'] = iris.target

# Display the first few rows of the dataset
print("Iris Dataset:")
print(iris_df.head())

# Display basic statistics of the features
print("\nStatistics of the Features:")
print(iris_df.describe())

# Display the distribution of the target classes
print("\nDistribution of Target Classes:")
print(iris_df['target'].value_counts())

# Visualize the dataset (pair plot)
import seaborn as sns
sns.pairplot(iris_df, hue='target', palette='Set1')
plt.show()
# Out:
# Iris Dataset:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#
# Statistics of the Features:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# ...

# %%
# Import necessary libraries
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier, export_text, plot_tree
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Load the Iris dataset as an example
iris = load_iris()
X, y = iris.data, iris.target

# Create a Pandas DataFrame for better visualization
iris_df = pd.DataFrame(data=X, columns=iris.feature_names)
iris_df['target'] = y

# Display the first few rows of the dataset
print("Iris Dataset:")
print(iris_df.head())

# Display basic statistics of the features
print("\nStatistics of the Features:")
print(iris_df.describe())

# Display the distribution of the target classes
print("\nDistribution of Target Classes:")
print(iris_df['target'].value_counts())

# Visualize the dataset (pair plot)
sns.pairplot(iris_df, hue='target', palette='Set1')
plt.show()

# Create a decision tree classifier
clf = DecisionTreeClassifier(random_state=42)

# Fit the classifier to the data
clf = clf.fit(X, y)

# Visualize the decision tree
fig, ax = plt.subplots(figsize=(12, 12))
plot_tree(clf, feature_names=iris.feature_names, class_names=iris.target_names, filled=True, rounded=True, ax=ax)
plt.show()
# Out:
# Iris Dataset:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#
# Statistics of the Features:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# ...

# %%
# Import necessary libraries
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier, export_text, plot_tree
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Load the Iris dataset as an example
iris = load_iris()
X, y = iris.data, iris.target

# Create a Pandas DataFrame for better visualization
iris_df = pd.DataFrame(data=X, columns=iris.feature_names)
iris_df['target'] = y

# Display the first few rows of the dataset
print("Iris Dataset:")
print(iris_df.head())

# Display basic statistics of the features
print("\nStatistics of the Features:")
print(iris_df.describe())

# Display the distribution of the target classes
print("\nDistribution of Target Classes:")
print(iris_df['target'].value_counts())

# Visualize the dataset (pair plot)
sns.pairplot(iris_df, hue='target', palette='Set1')
plt.show()

# Create a decision tree classifier
clf = DecisionTreeClassifier(random_state=42)

# Fit the classifier to the data
clf = clf.fit(X, y)

# Visualize the decision tree
fig, ax = plt.subplots(figsize=(12, 12))
plot_tree(clf, feature_names=iris.feature_names, class_names=iris.target_names, filled=True, rounded=True, ax=ax)
plt.show()
# Out:
# Iris Dataset:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#
# Statistics of the Features:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# ...
